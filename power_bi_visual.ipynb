# %% [markdown]
# Q.1  Create a Card Visual to show Total Sales.
#
# ...>> Step 1: Open Report View
#
# Open your Power BI Desktop file.
#
# Click on the Report View (chart icon on the left panel).
#
# Step 2: Create a Total Sales Measure (Recommended)
#
# Creating a measure ensures accuracy and reusability.
#
# Go to the Modeling tab.
#
# Click New Measure.
#
# Enter the following DAX formula:
#
# Total Sales = SUM(Sales[Sales])
#
#
# (Replace "Sales" with your actual table name if different.)
#
# Press Enter.
#
# Step 3: Insert the Card Visual
#
# In the Visualizations pane, click on the Card visual icon.
#
# A blank card will appear on the report canvas.
#
# Step 4: Add Total Sales to the Card
#
# You can do either of the following:
#
# Option A (Using Measure — Recommended):
#
# Drag the Total Sales measure into the Fields section of the Card visual.
#
# Option B (Using Column Directly):
#
# Drag the Sales column into the Card visual.
#
# Power BI will automatically calculate the Sum.
#
# Step 5: Format the Card (Optional but Recommended)
#
# Click on the Card → go to Format pane (paint roller icon):
#
# You can customize:
#
# Title → ON → Rename to: "Total Sales"
#
# Data label → Change font size (e.g., 30–40)
#
# Display units → Auto / Thousands / Millions
#
# Currency symbol → ₹ (if needed)
#
# Alignment → Center
#
# Final Result
#
# The Card visual will display something like:
#
# Total Sales
# ₹ 12,45,678
#
# This provides a quick KPI overview of overall sales.
#
# Q.2  Create a Donut Chart showing Total Sales by Ship Mode and which ship mode generates the highest sales ?
#
# ...>> Step 1: Open Report View
#
# Open your Power BI report.
#
# Click on Report View (left panel chart icon).
#
# Step 2: Ensure You Have Total Sales Measure (Recommended)
#
# Go to Modeling → New Measure, then enter:
#
# Total Sales = SUM(Sales[Sales])
#
#
# Press Enter.
#
# Step 3: Insert Donut Chart
#
# In the Visualizations pane, click on the Donut Chart icon.
#
# A blank donut chart will appear on the canvas.
#
# Step 4: Add Required Fields
#
# Drag the following fields:
#
# Ship Mode → Drag to Legend
#
# Total Sales (measure) → Drag to Values
#
# Power BI will now show Total Sales distribution by Ship Mode.
#
# Step 5: Turn on Data Labels (Recommended)
#
# Click the chart → Go to Format pane (paint roller icon) → Enable:
#
# Data labels → ON
#
# Show Value and Percentage
#
# Increase font size if needed
#
# Step 6: Identify the Highest Sales Ship Mode
#
# To clearly identify the highest:
#
# Method 1: Visual Method
#
# The largest slice in the donut chart represents the highest sales ship mode.
#
# Method 2: Sort Method
#
# Click the three dots (⋯) on the chart
#
# Select:
#
# Sort by → Total Sales
#
# Descending
#
# The top ship mode in legend is the highest.
#
# Step 7: Exact Value (Optional – Table View)
#
# You can also create a Table visual:
#
# Ship Mode
#
# Total Sales
#
# Sort descending to see the exact highest.
#
# Example result (sample):
#
# Ship Mode	Total Sales
# Standard Class	₹ 7,50,000 ✅ Highest
# Second Class	₹ 4,20,000
# First Class	₹ 2,80,000
# Same Day	₹ 1,50,000
# Final Conclusion (Typical Superstore Dataset)
#
# Standard Class generates the highest total sales.
#
# Q.3  Create a Line Chart showing the Sales Trend over time (by Month and Year). Is there any noticeables seasonal pattern in sales?
#
# ...>> Step 1: Open Report View
#
# Open your Power BI report.
#
# Click on Report View (chart icon on the left).
#
# Step 2: Ensure Date Column is in Date Format
#
# Go to Data View
#
# Select your Order Date column
#
# In the Column tools tab
#
# Set Data Type → Date
#
# Set Format → Date
#
# Step 3: Create Total Sales Measure (Recommended)
#
# Go to Modeling → New Measure
#
# Total Sales = SUM(Sales[Sales])
#
#
# Press Enter
#
# Step 4: Insert Line Chart
#
# In Visualizations pane, click Line Chart
#
# Drag the following fields:
#
# Order Date → Axis
#
# Total Sales → Values
#
# Step 5: Show Sales by Month and Year
#
# Power BI automatically creates a Date Hierarchy:
#
# Click the dropdown next to Order Date in Axis → Select:
#
# Date Hierarchy
#
# Then expand to show:
#
# Year
#
# Quarter
#
# Month
#
# Click the Expand All Down One Level button (double arrow icon) until Month is visible.
#
# This shows Month-wise trend across Years.
#
# Step 6: Format the Chart (Recommended)
#
# Go to Format pane →
#
# Turn ON:
#
# Title → "Sales Trend by Month and Year"
#
# Data labels → Optional
#
# X-axis → Show Year and Month clearly
#
# Step 7: Identify Seasonal Pattern
#
# Typical pattern observed in Superstore dataset:
#
# Seasonal Trends:
#
# 📈 Sales increase from September to December
#
# 📊 Highest sales usually in November and December
#
# 📉 Lowest sales usually in January and February
#
# 📈 Moderate growth in March to June
#
# 📉 Slight dip in July and August
#
# Final Conclusion
#
# Yes, there is a noticeable seasonal pattern:
#
# Peak Season: November and December (Holiday / Festival season)
#
# Low Season: January and February
#
# Reason: Holiday shopping, year-end corporate purchases, and promotions increase sales.
#
# Optional (Best Practice – Create Month-Year Column)
#
# Create a new column for cleaner axis:
#
# Month Year = FORMAT(Sales[Order Date], "MMM YYYY")
#
#
# Then sort it properly using Month Number.
#
# Q.4 Create a Bar Chart to compare Sales by Category.
#
# ...>>Step 1: Open Report View
#
# Open your Power BI Desktop file.
#
# Click on Report View (chart icon on the left panel).
#
# Step 2: Create Total Sales Measure (Recommended)
#
# Go to Modeling → New Measure, then enter:
#
# Total Sales = SUM(Sales[Sales])
#
#
# Press Enter.
#
# Step 3: Insert Bar Chart
#
# In the Visualizations pane, click on the Clustered Bar Chart icon.
#
# A blank bar chart will appear on the report canvas.
#
# Step 4: Add Required Fields
#
# Drag the following fields:
#
# Category → Drag to Y-axis
#
# Total Sales → Drag to X-axis
#
# Power BI will automatically create bars for each category.
#
# Step 5: Sort the Chart (Optional but Recommended)
#
# To identify highest and lowest sales:
#
# Click the three dots (⋯) on the chart
#
# Select
# Sort by → Total Sales → Descending
#
# The highest sales category will appear at the top.
#
# Step 6: Turn on Data Labels (Recommended)
#
# Go to Format pane (paint roller icon) → Turn ON:
#
# Data labels
#
# Title → "Sales by Category"
#
# Adjust font size if needed
#
# Step 7: Interpretation (Typical Superstore Dataset Result)
#
# Example:
#
# Category	Total Sales
# Technology	Highest Sales ✅
# Furniture	Medium Sales
# Office Supplies	Lowest Sales
# Final Conclusion
#
# The Bar Chart clearly compares sales across categories and helps identify that Technology usually generates the highest sales, followed by Furniture, then Office Supplies.
#
# Q.5  Create a Matrix Visual to display Sales by Month and Category and identify the month with the hightest sales
#
# ..>> Step 1: Create Total Sales Measure (Recommended)
#
# Go to Modeling → New Measure, then enter:
#
# Total Sales = SUM(Sales[Sales])
#
#
# Press Enter
#
# Step 2: Insert Matrix Visual
#
# Go to Report View
#
# In the Visualizations pane, click on the Matrix visual icon
#
# A blank matrix will appear on the canvas
#
# Step 3: Add Required Fields
#
# Drag the following fields into the Matrix:
#
# Order Date → Rows
#
# Category → Columns
#
# Total Sales → Values
#
# Step 4: Show Sales by Month and Year
#
# Power BI creates a Date hierarchy automatically.
#
# Click the dropdown next to Order Date in Rows
#
# Select Date Hierarchy
#
# Click Expand All Down One Level (double arrow icon) until Month is visible
#
# Now the matrix shows:
#
# Rows → Month
#
# Columns → Category
#
# Values → Total Sales
#
# Step 5: Enable Row Totals
#
# Go to Format pane → Grand Total
#
# Turn ON:
#
# Row Grand Total
#
# This will show total sales for each month.
#
# Step 6: Identify the Highest Sales Month
#
# Look at the Row Grand Total column.
#
# The month with the highest value is the highest sales month.
#
# Example (Typical Superstore Dataset):
#
# Month	Furniture	Office Supplies	Technology	Total Sales
# Jan	12,000	15,000	18,000	45,000
# Feb	10,000	13,000	17,000	40,000
# Nov	25,000	32,000	40,000	97,000
# Dec	28,000	35,000	45,000	108,000 ✅ Highest
# Step 7: Highlight Highest Month Automatically (Optional)
#
# Go to:
#
# Format pane → Conditional formatting → Background color → Based on Total Sales
#
# This visually highlights the highest month.
#
# Final Conclusion
#
# The Matrix Visual shows monthly sales by category, and typically November or December has the highest total sales, indicating strong year-end seasonal performance.
#
# Q.6  Create a Decomposition Tree for Sales Breakdown.
#
# ...>> Step 1: Create Total Sales Measure (Recommended)
#
# Go to Modeling → New Measure, then enter:
#
# Total Sales = SUM(Sales[Sales])
#
#
# Press Enter
#
# Step 2: Insert Decomposition Tree Visual
#
# Go to Report View
#
# In the Visualizations pane
#
# Click on the Decomposition Tree icon
#
# A blank decomposition tree will appear.
#
# Step 3: Add Fields to the Visual
#
# You will see two main sections:
#
# Analyze (Required)
#
# Drag:
#
# Total Sales → into Analyze
#
# This is the main metric you want to break down.
#
# Explain By (Breakdown Fields)
#
# Drag these fields into Explain by:
#
# Category
#
# Sub-Category
#
# Region
#
# Segment
#
# Ship Mode
#
# These fields allow drill-down analysis.
#
# Example:
#
# Analyze:
# Total Sales
#
# Explain by:
# Category
# Sub-Category
# Region
# Segment
# Ship Mode
#
# Step 4: Start Analyzing the Breakdown
#
# Click the + icon next to Total Sales.
#
# You can select:
#
# Category
#
# Region
#
# Segment
#
# etc.
#
# Example breakdown path:
#
# Total Sales
#    → Category
#        → Technology
#            → Sub-Category
#                → Phones (Highest)
#
# Step 5: Use AI Split (Optional but Powerful)
#
# Click + icon → Select:
#
# High Value → Shows highest contributor
#
# Low Value → Shows lowest contributor
#
# Power BI automatically finds key drivers.
#
# Step 6: Example Insights (Typical Superstore Dataset)
#
# Example breakdown:
#
# Total Sales: ₹ 22,97,201
#
# Highest Contributor:
# Category → Technology
# Sub-Category → Phones
# Region → West
# Segment → Consumer
#
#
# Lowest contributor might be:
#
# Category → Furniture
# Sub-Category → Fasteners
#
# Final Conclusion
#
# The Decomposition Tree helps you:
#
# Identify highest sales contributors
#
# Drill down step-by-step
#
# Find root causes of high or low sales
#
# Perform interactive root-cause analysis.
#
# Q.7 Create a Scatter Chart to compare Discount vs. Profit by Sub-Category. Are there any outliers
# where high discounts resulted in negative profit?
#
# ...>> Step 1: Create Required Measures (Recommended)
#
# Go to Modeling → New Measure, create:
#
# Total Profit = SUM(Sales[Profit])
#
# Average Discount = AVERAGE(Sales[Discount])
#
#
# These measures ensure accurate aggregation.
#
# Step 2: Insert Scatter Chart
#
# Go to Report View
#
# In the Visualizations pane, click the Scatter Chart icon
#
# A blank scatter chart appears
#
# Step 3: Add Required Fields
#
# Drag the following fields into the scatter chart:
#
# X-axis → Average Discount
#
# Y-axis → Total Profit
#
# Details → Sub-Category
#
# Size (Optional) → Total Sales
#
# Legend (Optional) → Category
#
# This will create one dot per sub-category.
#
# Step 4: Format the Chart (Recommended)
#
# Go to Format pane (paint roller icon):
#
# Turn ON:
#
# Data labels → ON
#
# Title → "Discount vs Profit by Sub-Category"
#
# Gridlines → ON (optional)
#
# Step 5: How to Identify Outliers
#
# Look for points where:
#
# Discount is high (right side of chart)
#
# Profit is negative (below zero line)
#
# These points represent loss-making sub-categories with high discounts.
#
# Step 6: Typical Insights (Superstore Dataset)
#
# Common outliers where high discount caused negative profit:
#
# Sub-Category	Discount	Profit	Insight
# Tables	High	Negative ❌	Major loss due to heavy discount
# Bookcases	High	Negative ❌	Frequent losses
# Supplies	Medium-High	Negative ❌	Poor profit performance
#
# High-profit, low-discount examples:
#
# Sub-Category	Discount	Profit
# Phones	Low	High ✅
# Copiers	Low	Very High ✅
# Final Conclusion
#
# Yes, there are clear outliers.
#
# Sub-Categories like Tables and Bookcases show high discounts but negative profit, indicating excessive discounting leads to losses.
#
# Business Recommendation
#
# Reduce discounts on loss-making sub-categories
#
# Optimize pricing strategy
#
# Focus on high-profit, low-discount products like Phones and Copiers.
#
# Q.8  Use a Funnel Chart to show the number of orders by Customer Segments.
#
# ...>> Step 1: Create Order Count Measure (Recommended)
#
# Go to Modeling → New Measure, then enter:
#
# Order Count = DISTINCTCOUNT(Sales[Order_ID])
#
#
# Why use DISTINCTCOUNT?
# It ensures each order is counted once, even if it has multiple items.
#
# Step 2: Insert Funnel Chart
#
# Go to Report View
#
# In the Visualizations pane
#
# Click the Funnel Chart icon
#
# A blank funnel chart will appear on the canvas
#
# Step 3: Add Required Fields
#
# Drag the following fields:
#
# Customer Segment (Segment) → Drag to Group
#
# Order Count (measure) → Drag to Values
#
# The funnel will now display the number of orders for each segment.
#
# Step 4: Sort the Funnel
#
# Click the three dots (⋯) on the visual → Select:
#
# Sort by → Order Count → Descending
#
# This ensures the largest segment appears at the top.
#
# Step 5: Turn on Data Labels (Recommended)
#
# Go to Format pane →
#
# Turn ON:
#
# Data labels → ON
#
# Title → "Number of Orders by Customer Segment"
#
# Step 6: Interpretation (Typical Superstore Dataset)
#
# Example:
#
# Customer Segment	Order Count
# Consumer	5,200 ✅ Highest
# Corporate	3,000
# Home Office	1,800 Lowest
# Final Conclusion
#
# The Funnel Chart shows that:
#
# Consumer segment places the highest number of orders
#
# Followed by Corporate
#
# Home Office has the lowest number of orders
#
# This helps identify the most valuable customer segment.
#
# Q.9 Use a Waterfall Chart to analyze how Profit changes by Category within the countries.
#
# ...>> Step 1: Create Total Profit Measure (Recommended)
#
# Go to Modeling → New Measure, then enter:
#
# Total Profit = SUM(Sales[Profit])
#
#
# Press Enter
#
# Step 2: Insert Waterfall Chart
#
# Go to Report View
#
# In the Visualizations pane
#
# Click the Waterfall Chart icon
#
# A blank waterfall chart will appear
#
# Step 3: Add Required Fields
#
# Drag the following fields into the visual:
#
# Country → Drag to Category
#
# Category → Drag to Breakdown
#
# Total Profit → Drag to Y-axis (Values)
#
# This configuration shows how each category contributes to profit within each country.
#
# Step 4: Sort the Chart (Optional but Recommended)
#
# Click three dots (⋯) → Select:
#
# Sort by → Total Profit → Descending
#
# Step 5: Turn on Data Labels
#
# Go to Format pane (paint roller icon) → Turn ON:
#
# Data labels → ON
#
# Title → "Profit Change by Category within Countries"
#
# Step 6: How to Interpret the Chart
#
# The Waterfall Chart shows:
#
# Each Country starts with total profit
#
# Then each Category (Furniture, Office Supplies, Technology) shows:
#
# Increase in profit (positive bars)
#
# Decrease in profit (negative bars)
#
# Example interpretation:
#
# Country: USA
#
# Technology → Large positive contribution ✅
#
# Office Supplies → Moderate positive contribution ✅
#
# Furniture → Small or negative contribution ❌
#
# Step 7: Key Insights (Typical Superstore Dataset)
#
# Technology contributes the highest profit in most countries
#
# Office Supplies contributes moderate profit
#
# Furniture sometimes reduces profit due to losses
#
# Optional: Drill Down View
#
# You can also structure it this way:
#
# Category → Country (switch positions)
#
# This shows profit change across countries for each category
#
# Final Conclusion
#
# The Waterfall Chart helps identify:
#
# Which category increases profit in each country
#
# Which category causes profit decline
#
# Technology is usually the strongest profit driver
#
# Furniture often has lower or negative profit impact.
#
# Q.10 Create a Dual-Axis Line Chart to show Total Sales and Profit Over Time (by Month).
#
# ..>> Step 1: Create Required Measures
#
# Go to Modeling → New Measure, create:
#
# Total Sales = SUM(Sales[Sales])
#
# Total Profit = SUM(Sales[Profit])
#
# Step 2: Insert Line Chart
#
# Go to Report View
#
# In the Visualizations pane
#
# Click the Line Chart icon
#
# Step 3: Add Fields to the Chart
#
# Drag the following fields:
#
# Order Date → Axis
#
# Total Sales → Values
#
# Total Profit → Values
#
# Power BI will show two lines on the same chart.
#
# Step 4: Show Data by Month and Year
#
# Click the dropdown next to Order Date in Axis
#
# Select Date Hierarchy
#
# Click Expand All Down One Level until Month is visible
#
# This shows trend by Month and Year.
#
# Step 5: Enable Secondary Axis (Dual Axis)
#
# Select the chart
#
# Go to Format pane (paint roller icon)
#
# Expand Y-axis
#
# Turn ON:
#
# Show secondary axis
#
# Assign:
#
# Total Sales → Primary Axis
#
# Total Profit → Secondary Axis
#
# Now both metrics are easier to compare.
#
# Step 6: Format the Chart (Recommended)
#
# Turn ON:
#
# Title → "Total Sales and Profit Over Time"
#
# Legend → ON
#
# Data labels → Optional
#
# Markers → ON (helps identify points clearly)
#
# Step 7: Interpretation
#
# Typical insights:
#
# Sales and Profit generally move together
#
# Months with high sales usually show high profit
#
# Some months may show high sales but lower profit due to:
#
# High discounts
#
# Increased costs
#
# Example pattern:
#
# Month	Sales	Profit
# Jan	Low	Low
# Mar	Medium	Medium
# Nov	High	High ✅
# Dec	Highest	Highest ✅
# Final Conclusion
#
# The Dual-Axis Line Chart helps you:
#
# Compare Sales and Profit trends simultaneously
#
# Identify profitable and unprofitable periods
#
# Detect seasonal patterns
#
# Monitor business performance over time.
